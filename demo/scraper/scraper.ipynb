# %%
import requests

# %%
response = requests.get('https://fitech.io/fi/opinnot/johdanto-datatieteeseen/')

# %%
response.text
# Out:
# '<!doctype html>\n<html class="no-js" lang="fi">\n\n      <head>\n  <meta charset="utf-8">\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n  <title>Johdanto datatieteeseen | FITech</title>\n<link rel="alternate" href="https://fitech.io/en/studies/johdanto-datatieteeseen/" hreflang="en" />\n<link rel="alternate" href="https://fitech.io/fi/opinnot/johdanto-datatieteeseen/" hreflang="fi" />\n\n<!-- The SEO Framework by Sybre Waaijer -->\n<meta name="description" content="Datatiede rakentuu nelj&auml;n laajan kokonaisuuden varaan: liiketoimintaosaaminen, ohjelmointi- ja tietokantaosaaminen, tilastollinen analyysi ja datal&auml;ht&ouml;inen&#8230;" />\n<meta property="og:image" content="https://fitech.io/app/uploads/2019/10/cropped-favicon.png" />\n<meta property="og:image:width" content="512" />\n<meta property="og:image:height" content="512" />\n<meta property="og:locale" content="fi_FI" 
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text)

# %%
soup.div
# Out:
# <div class="site-container">
# <header class="site-header">
# <nav class="navbar navbar-expand-lg bg-light py-3">
# <div class="container">
# <a class="navbar-brand" href="https://fitech.io/fi/">
#         Fitech
#         <svg height="40" viewbox="0 0 94 40" width="94" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="black">
# ...
